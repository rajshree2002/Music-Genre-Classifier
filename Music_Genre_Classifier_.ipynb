# %% [markdown]
# <a href="https://colab.research.google.com/github/rajshree2002/Music-Genre-Classifier/blob/main/Music_Genre_Classifier_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import librosa.display
import librosa
import IPython.display as id

# %%
music_data=pd.read_csv('/content/drive/MyDrive/Music Genre classifier/features_3_sec.csv')
music_data.head(5)
# Out:
#             filename  length  chroma_stft_mean  chroma_stft_var  rms_mean  \
# 0  blues.00000.0.wav   66149          0.335406         0.091048  0.130405
# 1  blues.00000.1.wav   66149          0.343065         0.086147  0.112699
# 2  blues.00000.2.wav   66149          0.346815         0.092243  0.132003
# 3  blues.00000.3.wav   66149          0.363639         0.086856  0.132565
# 4  blues.00000.4.wav   66149          0.335579         0.088129  0.143289
#
#     rms_var  spectral_centroid_mean  spectral_centroid_var  \
# 0  0.003521             1773.065032          167541.630869
# 1  0.001450             1816.693777           90525.690866
# 2  0.004620             1788.539719          111407.437613
# 3  0.002448             1655.289045          111952.284517
# 4  0.001701             1630.656199           79667.267654
#
#    spectral_bandwidth_mean  spectral_bandwidth_var  ...  mfcc16_var  \
# 0              1972.744388           117335.771563  ...   39.687145
# ...

# %%
music_data['label'].value_counts()
# Out:
# blues        1000
# jazz         1000
# metal        1000
# pop          1000
# reggae       1000
# disco         999
# classical     998
# hiphop        998
# rock          998
# country       997
# Name: label, dtype: int64

# %%
path = '/content/drive/MyDrive/Music Genre classifier/blues.00000.wav'
plt.figure(figsize=(14, 5))
x, sr = librosa.load(path)
plt.plot(x)
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.title('Waveform')
plt.show()

id.Audio(path)
print("Blue")
# Out:
# Blue

# %%
path = '/content/drive/MyDrive/Music Genre classifier/metal.00000.wav'
plt.figure(figsize=(14, 5))
x, sr = librosa.load(path)
plt.plot(x)
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.title('Waveform')
plt.show()

id.Audio(path)
print("Metal")
# Out:
# Metal

# %%
path = '/content/drive/MyDrive/Music Genre classifier/classical.00000.wav'
plt.figure(figsize=(14, 5))
x, sr = librosa.load(path)
plt.plot(x)
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.title('Waveform')
plt.show()

id.Audio(path)
print("Classical")
# Out:
# Classical

# %%
path = '/content/drive/MyDrive/Music Genre classifier/country.00000.wav'
plt.figure(figsize=(14, 5))
x, sr = librosa.load(path)
plt.plot(x)
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.title('Waveform')
plt.show()

id.Audio(path)
print("Country")
# Out:
# Country

# %%
path = '/content/drive/MyDrive/Music Genre classifier/disco.00000.wav'
plt.figure(figsize=(14, 5))
x, sr = librosa.load(path)
plt.plot(x)
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.title('Waveform')
plt.show()

id.Audio(path)
print("Disco")
# Out:
# Disco

# %%
path = '/content/drive/MyDrive/Music Genre classifier/hiphop.00000.wav'
plt.figure(figsize=(14, 5))
x, sr = librosa.load(path)
plt.plot(x)
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.title('Waveform')
plt.show()

id.Audio(path)
print("Hiphop")
# Out:
# Hiphop

# %%
path = '/content/drive/MyDrive/Music Genre classifier/jazz.00000.wav'
plt.figure(figsize=(14, 5))
x, sr = librosa.load(path)
plt.plot(x)
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.title('Waveform')
plt.show()

id.Audio(path)
print("Jazz")
# Out:
# Jazz

# %%
path = '/content/drive/MyDrive/Music Genre classifier/pop.00000.wav'
plt.figure(figsize=(14, 5))
x, sr = librosa.load(path)
plt.plot(x)
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.title('Waveform')
plt.show()

id.Audio(path)
print("Pop")
# Out:
# Pop

# %%
path = '/content/drive/MyDrive/Music Genre classifier/reggae.00000.wav'
plt.figure(figsize=(14, 5))
x, sr = librosa.load(path)
plt.plot(x)
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.title('Waveform')
plt.show()

id.Audio(path)
print("Reggae")
# Out:
# Reggae

# %%
path = '/content/drive/MyDrive/Music Genre classifier/rock.00000.wav'
plt.figure(figsize=(14, 5))
x, sr = librosa.load(path)
plt.plot(x)
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.title('Waveform')
plt.show()

id.Audio(path)
print("Rock")
# Out:
# Rock

# %%
import numpy as np
import seaborn as sns

# Computing the Correlation Matrix
spike_cols = [col for col in data.columns if 'mean' in col]

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(16, 11));

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(data[spike_cols].corr(), cmap='YlGn')

plt.title('Heatmap for MEAN variables', fontsize = 20)
plt.xticks(fontsize = 10)
plt.yticks(fontsize = 10);

# %%
from sklearn import preprocessing
label_encoder = preprocessing.LabelEncoder()
music_data['label'] = label_encoder.fit_transform(music_data['label'])

# %%
X = music_data.drop(['label','filename'],axis=1)
y = music_data['label']

# %%
cols = X.columns
minmax = preprocessing.MinMaxScaler()
np_scaled = minmax.fit_transform(X)

# new data frame with the new scaled data.
X = pd.DataFrame(np_scaled, columns = cols)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y,
													test_size=0.3,
													random_state=111)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((6993, 58), (2997, 58), (6993,), (2997,))

# %%
from sklearn.metrics import accuracy_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from xgboost import XGBClassifier

rf = RandomForestClassifier(n_estimators=1000, max_depth=10, random_state=0)
knn = KNeighborsClassifier()
dt = DecisionTreeClassifier()
xgb = XGBClassifier(n_estimators=1000, learning_rate=0.05)

classifiers = [rf, knn, dt, xgb]

for clf in classifiers:
    clf.fit(X_train, y_train)
    preds = clf.predict(X_test)
    print(clf.__class__.__name__, accuracy_score(y_test, preds))
# Out:
# RandomForestClassifier 0.8081414748081415
# KNeighborsClassifier 0.8932265598932265
# DecisionTreeClassifier 0.6536536536536537
# XGBClassifier 0.9095762429095763

# %%
import tensorflow.keras as keras
from tensorflow.keras import Sequential
from tensorflow.keras.layers import *

model = Sequential()

model.add(Flatten(input_shape=(58,)))
model.add(Dense(256, activation='relu'))
model.add(BatchNormalization())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(10, activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  flatten (Flatten)           (None, 58)                0
#
#  dense (Dense)               (None, 256)               15104
#
#  batch_normalization (BatchN  (None, 256)              1024
#  ormalization)
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_2 (Dense)             (None, 10)                1290
#
# ...
# Total params: 50,314
# Trainable params: 49,802
# Non-trainable params: 512
# _________________________________________________________________

# %%
# compile the model
adam = keras.optimizers.Adam(lr=1e-4)
model.compile(optimizer=adam,
			loss="sparse_categorical_crossentropy",
			metrics=["accuracy"])

hist = model.fit(X_train, y_train,
				validation_data = (X_test,y_test),
				epochs = 100,
				batch_size = 32)
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Epoch 1/100
# 219/219 [==============================] - 2s 3ms/step - loss: 1.2919 - accuracy: 0.5480 - val_loss: 1.7629 - val_accuracy: 0.4648
# Epoch 2/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.9502 - accuracy: 0.6670 - val_loss: 1.1639 - val_accuracy: 0.6143
# Epoch 3/100
# 219/219 [==============================] - 1s 2ms/step - loss: 0.8550 - accuracy: 0.7000 - val_loss: 1.0692 - val_accuracy: 0.6113
# Epoch 4/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.7860 - accuracy: 0.7233 - val_loss: 0.8567 - val_accuracy: 0.6890
# Epoch 5/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.7479 - accuracy: 0.7386 - val_loss: 0.8178 - val_accuracy: 0.7010
# Epoch 6/100
# ...

# %%
test_error, test_accuracy = model.evaluate(X_test, y_test, verbose=1)
print(f"Test accuracy: {test_accuracy}")
# Out:
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5973 - accuracy: 0.8312
# Test accuracy: 0.8311644792556763

# %%
fig, axs = plt.subplots(2,figsize=(10,10))

# accuracy
axs[0].plot(hist.history["accuracy"], label="train")
axs[0].plot(hist.history["val_accuracy"], label="test")
axs[0].set_ylabel("Accuracy")
axs[0].legend()
axs[0].set_title("Accuracy")

# Error
axs[1].plot(hist.history["loss"], label="train")
axs[1].plot(hist.history["val_loss"], label="test")
axs[1].set_ylabel("Error")
axs[1].legend()
axs[1].set_title("Error")

plt.show()
